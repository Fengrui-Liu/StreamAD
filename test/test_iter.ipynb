# %%
import json
import os
import sys

from numpy.core.defchararray import mod

# temporary solution for relative imports in case pyod is not installed
# if pyod is installed, no need to use the following line
sys.path.append(os.path.abspath(os.path.join(os.path.dirname("__file__"), "../..")))

import numpy as np
import pytest
from StreamAD.util import iter_item
import pdb
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-382b4c79e350> in <module>
#      11 import numpy as np
#      12 import pytest
# ---> 13 from StreamAD.util import iter_item
#      14 import pdb
#
# /mnt/c/Users/liufr/myPh.D/Code/StreamAD/StreamAD/util/__init__.py in <module>
#      10
#      11
# ---> 12 from .stream_generator import StreamGenerator
#      13
#      14
#
# /mnt/c/Users/liufr/myPh.D/Code/StreamAD/StreamAD/util/stream_generator.py in <module>
#      12 import numpy as np
#      13 import random
# ---> 14 import pd
#      15
#      16
#
# ModuleNotFoundError: No module named 'pd'

# %%
from sklearn.datasets import load_wine
import pandas as pd
dataset = load_wine()
X = dataset.data
Y = dataset.target

data_X = pd.DataFrame(X,columns=[dataset.feature_names])
data_Y = pd.DataFrame(Y,columns=["target"])
data = pd.concat([data_X,data_Y],axis=1)
data_Y
# Out:
#      target
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ..      ...
# 173       2
# 174       2
# 175       2
# 176       2
# 177       2
#
# [178 rows x 1 columns]

# %%
# row = next(data.iterrows())
for item in dataset.iterrows():
    print(item)
# Out:
#        13.36
# malic_acid                        2.56
# ash                               2.35
# alcalinity_of_ash                20.00
# magnesium                        89.00
# total_phenols                     1.40
# flavanoids                        0.50
# nonflavanoid_phenols              0.37
# proanthocyanins                   0.64
# color_intensity                   5.60
# hue                               0.70
# od280/od315_of_diluted_wines      2.47
# proline                         780.00
# Name: 141, dtype: float64)
# (142, alcohol                          13.52
# malic_acid                        3.17
# ash                               2.72
# alcalinity_of_ash                23.50
# magnesium                        97.00
# total_phenols                     1.55
# flavanoids                        0.52
# nonflavanoid_phenols              0.50
# proanthocyanins                   0.55
# color_intensity                   4.35
# hue                               0.89
# od280/od315_of_diluted_wines      2.06
# proline                         520.00
# Name: 142, dtype: float64)
# (143, alcohol                          13.62
# malic_acid                        4.95
# ash                               2.35
# alcalinity_of_ash                20.00
# magnesium                        92.00
# total_phenols                     2.00
# flavanoids                        0.80
# nonflavanoid_phenols              0.47
# proanthocyanins                   1.02
# color_intensity                   4.40
# hue                               0.91
# od280/od315_of_diluted_wines      2.05
# proline                         550.00
# Name: 143, dtype: float64)
# (144, alcohol                          12.25
# malic_acid                        3.88
# ash                               2.20
# alcalinity_of_ash                18.50
# magnesium                       112.00
# total_phenols                     1.38
# flavanoids                        0.78
# nonflavanoid_phenols              0.29
# proanthocyanins                   1.14
# color_intensity                   8.21
# hue                               0.65
# od280/od315_of_diluted_wines      2.00
# proline                         855.00
# Name: 144, dtype: float64)
# (145, alcohol                          13.16
# malic_acid                        3.57
# ash                               2.15
# alcalinity_of_ash                21.00
# magnesium                       102.00
# total_phenols                     1.50
# flavanoids                        0.55
# nonflavanoid_phenols              0.43
# proanthocyanins                   1.30
# color_intensity                   4.00
# hue                               0.60
# od280/od315_of_diluted_wines      1.68
# proline                         830.00
# Name: 145, dtype: float64)
# (146, alcohol                          13.88
# malic_acid                        5.04
# ash                               2.23
# alcalinity_of_ash                20.00
# magnesium                        80.00
# total_phenols                     0.98
# flavanoids                        0.34
# nonflavanoid_phenols              0.40
# proanthocyanins                   0.68
# color_intensity                   4.90
# hue                               0.58
# od280/od315_of_diluted_wines      1.33
# proline                         415.00
# Name: 146, dtype: float64)
# (147, alcohol                          12.87
# malic_acid                        4.61
# ash                               2.48
# alcalinity_of_ash                21.50
# magnesium                        86.00
# total_phenols                     1.70
# flavanoids                        0.65
# nonflavanoid_phenols              0.47
# proanthocyanins                   0.86
# color_intensity                   7.65
# hue                               0.54
# od280/od315_of_diluted_wines      1.86
# proline                         625.00
# Name: 147, dtype: float64)
# (148, alcohol                          13.32
# malic_acid                        3.24
# ash                               2.38
# alcalinity_of_ash                21.50
# magnesium                        92.00
# total_phenols                     1.93
# flavanoids                        0.76
# nonflavanoid_phenols              0.45
# proanthocyanins                   1.25
# color_intensity                   8.42
# hue                               0.55
# od280/od315_of_diluted_wines      1.62
# proline                         650.00
# Name: 148, dtype: float64)
# (149, alcohol                          13.08
# malic_acid                        3.90
# ash                               2.36
# alcalinity_of_ash                21.50
# magnesium                       113.00
# total_phenols                     1.41
# flavanoids                        1.39
# nonflavanoid_phenols              0.34
# proanthocyanins                   1.14
# color_intensity                   9.40
# hue                               0.57
# od280/od315_of_diluted_wines      1.33
# proline                         550.00
# Name: 149, dtype: float64)
# (150, alcohol                          13.50
# malic_acid                        3.12
# ash                               2.62
# alcalinity_of_ash                24.00
# magnesium                       123.00
# total_phenols                     1.40
# flavanoids                        1.57
# nonflavanoid_phenols              0.22
# proanthocyanins                   1.25
# color_intensity                   8.60
# hue                               0.59
# od280/od315_of_diluted_wines      1.30
# proline                         500.00
# Name: 150, dtype: float64)
# (151, alcohol                          12.79
# malic_acid                        2.67
# ash                               2.48
# alcalinity_of_ash                22.00
# magnesium                       112.00
# total_phenols                     1.48
# flavanoids                        1.36
# nonflavanoid_phenols              0.24
# proanthocyanins                   1.26
# color_intensity                  10.80
# hue                               0.48
# od280/od315_of_diluted_wines      1.47
# proline                         480.00
# Name: 151, dtype: float64)
# (152, alcohol                          13.11
# malic_acid                        1.90
# ash                               2.75
# alcalinity_of_ash                25.50
# magnesium                       116.00
# total_phenols                     2.20
# flavanoids                        1.28
# nonflavanoid_phenols              0.26
# proanthocyanins                   1.56
# color_intensity                   7.10
# hue                               0.61
# od280/od315_of_diluted_wines      1.33
# proline                         425.00
# Name: 152, dtype: float64)
# (153, alcohol                          13.23
# malic_acid                        3.30
# ash                               2.28
# alcalinity_of_ash                18.50
# magnesium                        98.00
# total_phenols                     1.80
# flavanoids                        0.83
# nonflavanoid_phenols              0.61
# proanthocyanins                   1.87
# color_intensity                  10.52
# hue                               0.56
# od280/od315_of_diluted_wines      1.51
# proline                         675.00
# Name: 153, dtype: float64)
# (154, alcohol                          12.58
# malic_acid                        1.29
# ash                               2.10
# alcalinity_of_ash                20.00
# magnesium                       103.00
# total_phenols                     1.48
# flavanoids                        0.58
# nonflavanoid_phenols              0.53
# proanthocyanins                   1.40
# color_intensity                   7.60
# hue                               0.58
# od280/od315_of_diluted_wines      1.55
# proline                         640.00
# Name: 154, dtype: float64)
# (155, alcohol                          13.17
# malic_acid                        5.19
# ash                               2.32
# alcalinity_of_ash                22.00
# magnesium                        93.00
# total_phenols                     1.74
# flavanoids                        0.63
# nonflavanoid_phenols              0.61
# proanthocyanins                   1.55
# color_intensity                   7.90
# hue                               0.60
# od280/od315_of_diluted_wines      1.48
# proline                         725.00
# Name: 155, dtype: float64)
# (156, alcohol                          13.84
# malic_acid                        4.12
# ash                               2.38
# alcalinity_of_ash                19.50
# magnesium                        89.00
# total_phenols                     1.80
# flavanoids                        0.83
# nonflavanoid_phenols              0.48
# proanthocyanins                   1.56
# color_intensity                   9.01
# hue                               0.57
# od280/od315_of_diluted_wines      1.64
# proline                         480.00
# Name: 156, dtype: float64)
# (157, alcohol                          12.45
# malic_acid                        3.03
# ash                               2.64
# alcalinity_of_ash                27.00
# magnesium                        97.00
# total_phenols                     1.90
# flavanoids                        0.58
# nonflavanoid_phenols              0.63
# proanthocyanins                   1.14
# color_intensity                   7.50
# hue                               0.67
# od280/od315_of_diluted_wines      1.73
# proline                         880.00
# Name: 157, dtype: float64)
# (158, alcohol                          14.34
# malic_acid                        1.68
# ash                               2.70
# alcalinity_of_ash                25.00
# magnesium                        98.00
# total_phenols                     2.80
# flavanoids                        1.31
# nonflavanoid_phenols              0.53
# proanthocyanins                   2.70
# color_intensity                  13.00
# hue                               0.57
# od280/od315_of_diluted_wines      1.96
# proline                         660.00
# Name: 158, dtype: float64)
# (159, alcohol                          13.48
# malic_acid                        1.67
# ash                               2.64
# alcalinity_of_ash                22.50
# magnesium                        89.00
# total_phenols                     2.60
# flavanoids                        1.10
# nonflavanoid_phenols              0.52
# proanthocyanins                   2.29
# color_intensity                  11.75
# hue                               0.57
# od280/od315_of_diluted_wines      1.78
# proline                         620.00
# Name: 159, dtype: float64)
# (160, alcohol                          12.36
# malic_acid                        3.83
# ash                               2.38
# alcalinity_of_ash                21.00
# magnesium                        88.00
# total_phenols                     2.30
# flavanoids                        0.92
# nonflavanoid_phenols              0.50
# proanthocyanins                   1.04
# color_intensity                   7.65
# hue                               0.56
# od280/od315_of_diluted_wines      1.58
# proline                         520.00
# Name: 160, dtype: float64)
# (161, alcohol                          13.69
# malic_acid                        3.26
# ash                               2.54
# alcalinity_of_ash                20.00
# magnesium                       107.00
# total_phenols                     1.83
# flavanoids                        0.56
# nonflavanoid_phenols              0.50
# proanthocyanins                   0.80
# color_intensity                   5.88
# hue                               0.96
# od280/od315_of_diluted_wines      1.82
# proline                         680.00
# Name: 161, dtype: float64)
# (162, alcohol                          12.85
# malic_acid                        3.27
# ash                               2.58
# alcalinity_of_ash                22.00
# magnesium                       106.00
# total_phenols                     1.65
# flavanoids                        0.60
# nonflavanoid_phenols              0.60
# proanthocyanins                   0.96
# color_intensity                   5.58
# hue                               0.87
# od280/od315_of_diluted_wines      2.11
# proline                         570.00
# Name: 162, dtype: float64)
# (163, alcohol                          12.96
# malic_acid                        3.45
# ash                               2.35
# alcalinity_of_ash                18.50
# magnesium                       106.00
# total_phenols                     1.39
# flavanoids                        0.70
# nonflavanoid_phenols              0.40
# proanthocyanins                   0.94
# color_intensity                   5.28
# hue                               0.68
# od280/od315_of_diluted_wines      1.75
# proline                         675.00
# Name: 163, dtype: float64)
# (164, alcohol                          13.78
# malic_acid                        2.76
# ash                               2.30
# alcalinity_of_ash                22.00
# magnesium                        90.00
# total_phenols                     1.35
# flavanoids                        0.68
# nonflavanoid_phenols              0.41
# proanthocyanins                   1.03
# color_intensity                   9.58
# hue                               0.70
# od280/od315_of_diluted_wines      1.68
# proline                         615.00
# Name: 164, dtype: float64)
# (165, alcohol                          13.73
# malic_acid                        4.36
# ash                               2.26
# alcalinity_of_ash                22.50
# magnesium                        88.00
# total_phenols                     1.28
# flavanoids                        0.47
# nonflavanoid_phenols              0.52
# proanthocyanins                   1.15
# color_intensity                   6.62
# hue                               0.78
# od280/od315_of_diluted_wines      1.75
# proline                         520.00
# Name: 165, dtype: float64)
# (166, alcohol                          13.45
# malic_acid                        3.70
# ash                               2.60
# alcalinity_of_ash                23.00
# magnesium                       111.00
# total_phenols                     1.70
# flavanoids                        0.92
# nonflavanoid_phenols              0.43
# proanthocyanins                   1.46
# color_intensity                  10.68
# hue                               0.85
# od280/od315_of_diluted_wines      1.56
# proline                         695.00
# Name: 166, dtype: float64)
# (167, alcohol                          12.82
# malic_acid                        3.37
# ash                               2.30
# alcalinity_of_ash                19.50
# magnesium                        88.00
# total_phenols                     1.48
# flavanoids                        0.66
# nonflavanoid_phenols              0.40
# proanthocyanins                   0.97
# color_intensity                  10.26
# hue                               0.72
# od280/od315_of_diluted_wines      1.75
# proline                         685.00
# Name: 167, dtype: float64)
# (168, alcohol                          13.58
# malic_acid                        2.58
# ash                               2.69
# alcalinity_of_ash                24.50
# magnesium                       105.00
# total_phenols                     1.55
# flavanoids                        0.84
# nonflavanoid_phenols              0.39
# proanthocyanins                   1.54
# color_intensity                   8.66
# hue                               0.74
# od280/od315_of_diluted_wines      1.80
# proline                         750.00
# Name: 168, dtype: float64)
# (169, alcohol                          13.40
# malic_acid                        4.60
# ash                               2.86
# alcalinity_of_ash                25.00
# magnesium                       112.00
# total_phenols                     1.98
# flavanoids                        0.96
# nonflavanoid_phenols              0.27
# proanthocyanins                   1.11
# color_intensity                   8.50
# hue                               0.67
# od280/od315_of_diluted_wines      1.92
# proline                         630.00
# Name: 169, dtype: float64)
# (170, alcohol                          12.20
# malic_acid                        3.03
# ash                               2.32
# alcalinity_of_ash                19.00
# magnesium                        96.00
# total_phenols                     1.25
# flavanoids                        0.49
# nonflavanoid_phenols              0.40
# proanthocyanins                   0.73
# color_intensity                   5.50
# hue                               0.66
# od280/od315_of_diluted_wines      1.83
# proline                         510.00
# Name: 170, dtype: float64)
# (171, alcohol                          12.770000
# malic_acid                        2.390000
# ash                               2.280000
# alcalinity_of_ash                19.500000
# magnesium                        86.000000
# total_phenols                     1.390000
# flavanoids                        0.510000
# nonflavanoid_phenols              0.480000
# proanthocyanins                   0.640000
# color_intensity                   9.899999
# hue                               0.570000
# od280/od315_of_diluted_wines      1.630000
# proline                         470.000000
# Name: 171, dtype: float64)
# (172, alcohol                          14.16
# malic_acid                        2.51
# ash                               2.48
# alcalinity_of_ash                20.00
# magnesium                        91.00
# total_phenols                     1.68
# flavanoids                        0.70
# nonflavanoid_phenols              0.44
# proanthocyanins                   1.24
# color_intensity                   9.70
# hue                               0.62
# od280/od315_of_diluted_wines      1.71
# proline                         660.00
# Name: 172, dtype: float64)
# (173, alcohol                          13.71
# malic_acid                        5.65
# ash                               2.45
# alcalinity_of_ash                20.50
# magnesium                        95.00
# total_phenols                     1.68
# flavanoids                        0.61
# nonflavanoid_phenols              0.52
# proanthocyanins                   1.06
# color_intensity                   7.70
# hue                               0.64
# od280/od315_of_diluted_wines      1.74
# proline                         740.00
# Name: 173, dtype: float64)
# (174, alcohol                          13.40
# malic_acid                        3.91
# ash                               2.48
# alcalinity_of_ash                23.00
# magnesium                       102.00
# total_phenols                     1.80
# flavanoids                        0.75
# nonflavanoid_phenols              0.43
# proanthocyanins                   1.41
# color_intensity                   7.30
# hue                               0.70
# od280/od315_of_diluted_wines      1.56
# proline                         750.00
# Name: 174, dtype: float64)
# (175, alcohol                          13.27
# malic_acid                        4.28
# ash                               2.26
# alcalinity_of_ash                20.00
# magnesium                       120.00
# total_phenols                     1.59
# flavanoids                        0.69
# nonflavanoid_phenols              0.43
# proanthocyanins                   1.35
# color_intensity                  10.20
# hue                               0.59
# od280/od315_of_diluted_wines      1.56
# proline                         835.00
# Name: 175, dtype: float64)
# (176, alcohol                          13.17
# malic_acid                        2.59
# ash                               2.37
# alcalinity_of_ash                20.00
# magnesium                       120.00
# total_phenols                     1.65
# flavanoids                        0.68
# nonflavanoid_phenols              0.53
# proanthocyanins                   1.46
# color_intensity                   9.30
# hue                               0.60
# od280/od315_of_diluted_wines      1.62
# proline                         840.00
# Name: 176, dtype: float64)
# (177, alcohol                          14.13
# malic_acid                        4.10
# ash                               2.74
# alcalinity_of_ash                24.50
# magnesium                        96.00
# total_phenols                     2.05
# flavanoids                        0.76
# nonflavanoid_phenols              0.56
# proanthocyanins                   1.35
# color_intensity                   9.20
# hue                               0.61
# od280/od315_of_diluted_wines      1.60
# proline                         560.00
# Name: 177, dtype: float64)
